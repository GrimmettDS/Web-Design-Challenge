# %%
import pandas as pd

# %%
weather_data_df = pd.read_csv("Resources/city_weather_main.csv")
weather_data_df.head()
# Out:
#             City Country  Latitude  Longitude  Cloudiness        Date   Wind  \
# 0  Krasnosel'kup      RU     65.70      82.47         100  1608498733   4.05
# 1       Thompson      CA     55.74     -97.86          90  1608498733   4.70
# 2         Albany      US     42.60     -73.97         100  1608498660   1.01
# 3         Atuona      PF     -9.80    -139.03          35  1608498734  16.91
# 4  Pozo Colorado      PY    -23.49     -58.80         100  1608498734  11.52
#
#    Humidity  Max Temp
# 0        92     -2.09
# 1        69     -9.40
# 2        73     32.00
# 3        76     78.71
# 4        70     81.03

# %%
weather_data_html = weather_data_df.to_html()
weather_data_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Country</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Cloudiness</th>\n      <th>Date</th>\n      <th>Wind</th>\n      <th>Humidity</th>\n      <th>Max Temp</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Krasnosel\'kup</td>\n      <td>RU</td>\n      <td>65.70</td>\n      <td>82.47</td>\n      <td>100</td>\n      <td>1608498733</td>\n      <td>4.05</td>\n      <td>92</td>\n      <td>-2.09</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Thompson</td>\n      <td>CA</td>\n      <td>55.74</td>\n      <td>-97.86</td>\n      <td>90</td>\n      <td>1608498733</td>\n      <td>4.70</td>\n      <td>69</td>\n      <td>-9.40</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Albany</td>\n      <td>US</td>\n      <td>42.60</td>\n      <td>-73.97</td>\n      <td>100</td>\n      <td>1608498660</td>\n     
# ...

# %%
print(weather_data_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Country</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Cloudiness</th>
#       <th>Date</th>
#       <th>Wind</th>
#       <th>Humidity</th>
#       <th>Max Temp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Krasnosel'kup</td>
#       <td>RU</td>
#       <td>65.70</td>
#       <td>82.47</td>
#       <td>100</td>
#       <td>1608498733</td>
#       <td>4.05</td>
#       <td>92</td>
#       <td>-2.09</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Thompson</td>
#       <td>CA</td>
#       <td>55.74</td>
#       <td>-97.86</td>
#       <td>90</td>
#       <td>1608498733</td>
#       <td>4.70</td>
#       <td>69</td>
#       <td>-9.40</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Albany</td>
#       <td>US</td>
#       <td>42.60</td>
#       <td>-73.97</td>
# ...

# %%
weather_data_df.to_html('weather_data_web.html')
